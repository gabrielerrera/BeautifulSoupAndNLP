# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielerrera/BeautifulSoupAndNLP/blob/main/FatecEstagio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os
import requests
from bs4 import BeautifulSoup

# %%
BASE_URL = "http://www.fatec.edu.br/category/aluno/"
DATA_DIR = "fatec"

# %%
response = requests.get(BASE_URL)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="pt-BR">\n<head profile="http://gmpg.org/xfn/11">\n\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n\t<title>Fatec Americana |   Portal do Aluno</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\n    <link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,700&subset=latin,latin-ext\' rel=\'stylesheet\' type=\'text/css\'>\n    <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">\n    <link rel="icon" href="http://www.fatec.edu.br/wp-content/themes/fatec/img/icon-32x32.png" sizes="32x32" />\n    <link rel="icon" href="http://www.fatec.edu.br/wp-content/themes/fatec/img/icon-192x192.png" sizes="192x192" />\n    <link rel="apple-touch-icon-precomposed" href="http://www.fatec.edu.br/wp-content/themes/fatec/img/icon-180x180.png" />\n    <meta name="msapplication-TileImage" content="http://www.fatec.edu.br/wp-content/themes/fatec/img/icon-270x270.png" />\n    <script src="http://www.fatec.edu.br/wp-content/themes/fatec/js/clipboard.min.js"></script>\n    <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.2/jquery.min.js"></script>\n    <script src="http://www.fatec.edu.br/wp-content/themes/fatec/js/fatec.js"></script>\n    <script>$(document).ready(function(){$("a").on(\'click\', function(event) {if (this.hash !== "") {event.preventDefault(); var hash = this.hash; $(\'html, body\').animate({ scrollTop: $(hash).offset().top}, 800, function(){window.location.hash = hash;});}});});</script>\n    <link href=http://www.fatec.edu.br/wp-content/themes/fatec/style.php rel="stylesheet">\n    <meta property="og:url"                content="http://www.fatec.edu.br/category/aluno" />\n<meta property="og:type"               content="article" />\n<meta property="og:title"              content="Lançamento do sistema piloto do Repositório Institucional do Conhecimento do Centro Paula Souza – RIC-CPS" />\n<meta property="og:description"        content="\xa0Repositório Institucional do Conhecimento do Centro Paula Souza – RIC-CPS É com grande prazer que a Fatec-AM comunica à sua comunidade, o lançamento do sistema piloto do Repositório Institucional do Conhecimento do Centro Paula Souza (RIC-CPS) em 1 de dezembro de 2017. O RIC-CPS é uma ferramenta informatizada capaz de gerenciar, armazenar, preservar e disseminar [&hellip;]" />\n<meta property="og:image"              content="http://www.fatec.edu.br/wp-content/themes/fatec/img/opengraph.png" />\n<style>\n    .aviso-container{\n        width: 100%;\n        margin: auto;\n        height: 100%;\n        position: fixed;\n        z-index: 9999;\n        background-color: #000000cc;\n    }\n    .aviso-container .aviso{\n        width: 450px;\n        max-width: 95vw;\n        margin: auto;\n        margin-top: 10%;\n        background-color: #ffffff;\n        border-radius: 6px;\n    }\n    .aviso-container h3{\n        font-size: 42px;\n        background-color: black;\n        color: white;\n        border-top-left-radius: 5px;\n        text-align: center;\n        border-top-right-radius: 5px;\n        margin-bottom: 0px;\n    }\n    .aviso-container p{\n        font-size: 20px;\n        padding: 16px;\n        padding-bottom: 33px;\n        text-align: center;\n    }\n    .aviso-container button{\n        height: 30px;\n        margin-top: 10px;\n        font-size: 18px;\n    }\n</style>\n</head><body><!--div class="aviso-container" id="avco" style="">\n    <div class="aviso">\n        <h3>COMUNICADO FATECS E ETECS</h3>\n        <p>Centro Paula Souza suspende as aulas nas Fatecs a partir de segunda-feira (16/03/2020)\n            e nas Etecs, a partir de 23/03/2020<br>\n            <button onclick="javascript:document.getElementById(\'avco\').style.display=\'none\'">\n                Fechar aviso\n            </button>\n        </p>\n    </div>\n</div--><div class="perguntaLinkContainer">\n        <div class="perguntaLin ...

# %%
bs = BeautifulSoup(response.text)

# %%
vagas = bs.find_all(class_="modal")

# %%
vagas
# Out:
# [<div class="modal" id="myModal6342">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6342').style.display ='none'">×</span>
#  <strong>DESENVOLVEDOR DE SOFTWARE</strong>
#  <p>Qualidades Pessoais:<br/>
#  - Ter proatividade em resolução de problemas na área de Desenvolvimento de Software.<br/>
#  - Ter um bom Relacionamento interpessoal<br/>
#  <br/>
#  Habilidades / Conhecimentos com experiência:<br/>
#  - JAVA para Web.<br/>
#  - SQL<br/>
#  <br/>
#  O que seria muito legal que você soubesse:<br/>
#  - Spring boot<br/>
#  - Interpretação de material técnico em inglês<br/>
#  - HTML, CSS e Javascript<br/>
#  -Angular<br/>
#  -Git<br/>
#  -Desenvolvimento Mobile<br/>
#  <br/>
#  Os interessados deverão encaminhar currículo no e-mail: <a href="mailto:roger.ferreira@iscoolapp.com.br" rel="noopener noreferrer" target="_blank">roger.ferreira@iscoolapp.com.br</a> com o assunto: Vaga DESENVOLVEDOR DE SOFTWARE.</p>
#  </div>
#  </div>, <div class="modal" id="myModal6334">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6334').style.display ='none'">×</span>
#  <strong>ASSISTENTE TECNOLOGIA DA INFORMAÇÃO</strong>
#  <p>Resumo das atividades a serem realizadas: <br/>
#  * Manutenção de computadores: <br/>
#  * Suporte aos professores, alunos e corpo administrativo: <br/>
#  * Suporte áudio visual <br/>
#  * Infraestrutura <br/>
#  <br/>
#  Horário de trabalho: 2ª a 6ª das 13h as 22h aos sábados das 9h as 13h<br/>
#  <br/>
#  Interessados enviar currículo para <a href="mailto:rayane.souza@uniesp.edu.br" rel="noopener noreferrer" target="_blank">rayane.souza@uniesp.edu.br</a></p>
#  </div>
#  </div>, <div class="modal" id="myModal6315">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6315').style.display ='none'">×</span>
#  <strong>Auxiliar de Estoque</strong>
#  <p><strong>Para alunos de Logística:</strong><br/>
#  <br/>
#  Responsabilidades: Realizar o controle de estoque. Recebimento de mercadorias. Saída de mercadorias. Manuseio de planilhas de Excel e sistema.<br/>
#  <br/>
#  Requisitos: <br/>
#  - Ensino Médio Completo; <br/>
#  - Experiência na área de estoque; <br/>
#  - Residir em Americana ou Santa Bárbara d’Oeste.<br/>
#  - Conhecimento básico em Excel<br/>
#  <br/>
#  Salário: a combinar<br/>
#  <br/>
#  Benefícios: Remuneração: R$1.257,00 + Vale Refeição + Vale Transporte + Plano de Saúde + Plano Odontológico<br/>
#  <br/>
#  Os currículos devem ser encaminhados para o e-mail <a href="mailto:vagas@alatererh.com.br" rel="noopener noreferrer" target="_blank">vagas@alatererh.com.br</a> com as siglas <strong>AUX. ESTOQUE</strong> no assunto.<br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6314">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6314').style.display ='none'">×</span>
#  <strong>Auxiliar de Suporte Técnico</strong>
#  <p><strong>Para alunos dos cursos relacionados com TI </strong><br/>
#  <br/>
#  Responsabilidades: Atender aos chamados sobre o sistema para tirar dúvidas; Auxiliar no suporte técnico da empresa; Realizar a formatação de computadores; Instalar impressoras; Dar suporte a equipe, entre outras atividades pertinentes a Help Desk.<br/>
#  <br/>
#  Requisitos: <br/>
#  - Superior em andamento; <br/>
#  - Experiência na área; <br/>
#  - Residir em Americana ou Santa Bárbara d’Oeste.<br/>
#  <br/>
#  Salário: R$ 1.600,00<br/>
#  <br/>
#  Benefícios: Assistência Médica + Vale Transporte + Vale Refeição<br/>
#  <br/>
#  Os currículos devem ser encaminhados para o e-mail <a href="mailto:vagas@alatererh.com.br" rel="noopener noreferrer" target="_blank">vagas@alatererh.com.br</a> com as siglas <strong>SUPORTE TÉCNICO</strong> no assunto.</p>
#  </div>
#  </div>, <div class="modal" id="myModal6313">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6313').style.display ='none'">×</span>
#  <strong>Vaga desenvolvedor Junior</strong>
#  <p>A Enviabybus é uma startup no ramo de logística com a pretensão de se tornar a empresa com a tecnologia mais avançada no ramo no Brasil. Para atingir esse objetivo, temos uma equipe apenas com grandes talentos, e agora precisamos complementar a equipe com pessoas com grande potencial.<br/>
#  <br/>
#  Para saber mais sobre a empresa entre em <a href="https://www.enviabybus.com.br" rel="noopener noreferrer" target="_blank">https://www.enviabybus.com.br</a><br/>
#  <br/>
#  Nosso stack de tecnologia<br/>
#  • Angular e React.js<br/>
#  • Sistema distribuído (micro serviços) utilizando Node.js e express<br/>
#  • Aplicativo mobile escrito em React Native<br/>
#  • Docker em todos os serviços<br/>
#  • Infraestrutura serverless utilizando Google Cloud Run<br/>
#  • MySQL<br/>
#  <br/>
#  O que você precisa ter<br/>
#  • Conhecimentos intermediários em lógica e programação<br/>
#  • Facilidade em aprender coisas por conta própria<br/>
#  • Inglês intermediário para leitura<br/>
#  <br/>
#  Formulário para candidatura de vaga: <a href="https://forms.gle/cfMH7k7wuACAXynx6" rel="noopener noreferrer" target="_blank">https://forms.gle/cfMH7k7wuACAXynx6</a></p>
#  </div>
#  </div>, <div class="modal" id="myModal6309">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6309').style.display ='none'">×</span>
#  <strong>PROCESSO SELETIVO DE ESTÁGIO INSTITUTO DE COMPUTAÇÃO – IC</strong>
#  <p>UNIVERSIDADE ESTADUAL DE CAMPINAS (UNICAMP) - INSTITUTO DE COMPUTAÇÃO<br/>
#  <br/>
#  Carga horária: 30 horas semanais, sendo 6 horas por dia de segunda a sexta-feira, das 8H30 às 14H45, com 15 minutos de intervalo para refeição.<br/>
#  <br/>
#  Remuneração: Bolsa-estágio de R$ 902,14 + auxílio transporte em Campinas.(duas passagens em dias de trabalho presencial)<br/>
#  <br/>
#  Descrição das atividades:<br/>
#  ● Identificar problemas com estação de trabalho<br/>
#  ● Auxiliar no suporte e na utilização de softwares com os usuários<br/>
#  ● Realizar configurações de SOs e configurações gerais de aplicações<br/>
#  ● Auxiliar na configuração de redes<br/>
#  ● Fazer levantamento de inventário<br/>
#  ● Auxiliar videoconferência e apoio às salas de aula e auditórios<br/>
#  ● Testar cabos e identificar problemas de hardware.<br/>
#  <br/>
#  Pré-requisitos:<br/>
#  ● Ser aluno de graduação regularmente matriculado em cursos da área de Tecnologia da Informação (Ciência da Computação, Engenharia de Computação, Análise e Desenvolvimento de Sistemas, Tecnólogo em Redes de Computadores, Tecnólogo em Segurança da Informação e afins)<br/>
#  <br/>
#  Requisitos desejáveis:<br/>
#  ● Desejável conhecimento em Windows, Linux, pacote Office (diferencial conhecimento em redes e hardware).<br/>
#  ● Para um primeiro momento é necessário alguns dias da semana trabalhar de casa, com isso é necessário que o candidato tenha um computador com acesso a internet para desempenhar atividades remotas.<br/>
#  <br/>
#  Critérios de seleção: Análise curricular e entrevista.<br/>
#  <br/>
#  Cronograma:<br/>
#  ● Até 03/02 - Submissão de currículo e preenchimento de dados em: <a href="https://forms.gle/V3vgLD4xr1HJay8E6" rel="noopener noreferrer" target="_blank">https://forms.gle/V3vgLD4xr1HJay8E6</a><br/>
#  ● 08 a 12/02 - Entrevistas<br/>
#  ● Previsão de início do estágio: 01/03/2021<br/>
#  ● Término em 31/12/2021, pode ser prorrogado com interesse das partes<br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6278">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6278').style.display ='none'">×</span>
#  <strong>🚀 Engenheiro de Hardware</strong>
#  <p>Local: Araraquara/SP<br/>
#  Contratação: PJ (MEI)<br/>
#  Compensação: R$ 65.000,00/ano (R$ 5.000,00/mês) &gt;negociável<br/>
#  Mais informações sobre nossa cultura e projetos em nosso site: <a href="http://r2t.company" rel="noopener noreferrer" target="_blank">http://r2t.company</a><br/>
#  <br/>
#  🎯 Habilidades:<br/>
#  -Graduação em Engenharia Mecatrônica, Eletrônica, Elétrica ou de Telecomunicações<br/>
#  -Ter noções de desenho técnico;<br/>
#  -Construir peças para fabricação em fornecedores de impressão 3D, corte, CNC, etc;<br/>
#  -Saber lidar com ESP e seus detalhes.<br/>
#  -Saber programar em C.<br/>
#  -Ter noções de Python e nuvem<br/>
#  <br/>
#  🎯 Diferenciais:<br/>
#  Desejável ter atuado no desenvolvimento de equipamentos de tecnologia e vivência com gestão de qualidade. Responsável por desenvolver e testar soluções de projeto de hardware eletrônico.<br/>
#  <br/>
#  🎯Perfil:<br/>
#  Facilidade de trabalhar em equipe; Responsabilidade para lidar com projetos em produção;<br/>
#  Capacidade de adquirir novos conhecimentos rapidamente; Habilidade de trabalho colaborativo; Ser<br/>
#  responsável por suas entregas.<br/>
#  <br/>
#  🎯 Ambiente de trabalho:<br/>
#  Horário flexível<br/>
#  Buscamos ter um ambiente diverso, aberto e liberal<br/>
#  Free snacks<br/>
#  Trabalhamos somente com a contratação de MEI (PJ), mas daremos todo o suporte se caso você não tiver.<br/>
#  Envie seu currículo para o e-mail com o assunto: PS2021/01 - SEU NOME - Vaga Engenheiro de Hardware para: <a href="mailto:recrutamento@r2t.company" rel="noopener noreferrer" target="_blank">recrutamento@r2t.company</a></p>
#  </div>
#  </div>, <div class="modal" id="myModal6277">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6277').style.display ='none'">×</span>
#  <strong>🚀 Backend .NET Core</strong>
#  <p>Local: Araraquara/SP<br/>
#  Compensação: R$ 39.000,00/ano (R$ 3.000/ mês) &gt;negociável<br/>
#  Mais informações sobre nossa cultura e projetos em nosso site: <a href="http://r2t.company" rel="noopener noreferrer" target="_blank">http://r2t.company</a><br/>
#  <br/>
#  🎯Habilidades:<br/>
#  -Domínio técnico e experiência com .NET Core e OOP<br/>
#  -Conhecimento e experiência em implementações com banco de dados MongoDB ou não-relacionais<br/>
#  e SQL (MySQL, Postgree)<br/>
#  -Conhecer o ambiente AWS ou Azure e como utilizar seus recursos para desenvolvimento em backend<br/>
#  -Conhecimento e domínio de git<br/>
#  -Conhecimento em Node Noções de DevOps<br/>
#  <br/>
#  🎯Diferenciais:<br/>
#  Conhecimentos em bash script ou powershell; conhecimento em linguagens como Python e Go;<br/>
#  tecnologias serverless como AWS Lambda e Firebase Functions; filas e serviços de mensagem como<br/>
#  AWS SQS e SNS; banco de dados Real-time Firebase.<br/>
#  <br/>
#  🎯Perfil:<br/>
#  Capacidade lógica para construção de algoritmos; Facilidade de trabalhar em equipe;<br/>
#  Responsabilidade para lidar com projetos em produção; Vontade de aprender novas tecnologias;<br/>
#  Colaborativo; Ser responsável por suas entregas.<br/>
#  <br/>
#  🎯Ambiente de trabalho:<br/>
#  Horário flexível<br/>
#  Free snacks<br/>
#  Trabalhamos somente com a contratação de MEI (PJ), mas daremos todo o suporte se caso você não tiver.<br/>
#  Envie seu currículo para o e-mail com o assunto: PS2021/01 - SEU NOME - Vaga Backend para: <a href="mailto:recrutamento@r2t.company" rel="noopener noreferrer" target="_blank">recrutamento@r2t.company</a></p>
#  </div>
#  </div>, <div class="modal" id="myModal6276">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6276').style.display ='none'">×</span>
#  <strong>🚀Tester</strong>
#  <p>Local: Araraquara/SP<br/>
#  Contratação: PJ (MEI)<br/>
#  Compensação: R$ 30.000,00/ ano (R$ 2.300,00/ mês) &gt;negociável<br/>
#  Mais informações sobre nossa cultura e projetos em nosso site: <a href="http://r2t.company" rel="noopener noreferrer" target="_blank">http://r2t.company</a><br/>
#  <br/>
#  🎯 Habilidades:<br/>
#  -Experiência com Jest ou Puppeteer<br/>
#  -Publicação de Apps em lojas como AppStore e Playstore<br/>
#  -Escrita de documentação<br/>
#  -GIT<br/>
#  <br/>
#  🎯 Diferenciais:<br/>
#  Experiência com QA; Familiaridade com metodologias ágeis; Facilidade de trabalhar em equipe;<br/>
#  Responsabilidade para lidar com projetos em produção; Vontade de aprender novas tecnologias;<br/>
#  Capacidade de adquirir novos conhecimentos rapidamente; Habilidade de trabalho colaborativo e descontraído; <br/>
#  Ter atitude de dono/ser responsável por suas entregas.<br/>
#  <br/>
#  🎯 Ambiente de trabalho: Horário flexível.<br/>
#  Buscamos ter um ambiente diverso, aberto e liberal<br/>
#  Free snacks<br/>
#  Trabalhamos somente com a contratação de MEI (PJ), mas daremos todo o suporte se caso você não tiver.<br/>
#  <br/>
#  Envie seu currículo para o e-mail com o assunto: PS2021/01 - SEU NOME - Vaga Tester para: <a href="mailto:recrutamento@r2t.company" rel="noopener noreferrer" target="_blank">recrutamento@r2t.company</a></p>
#  </div>
#  </div>, <div class="modal" id="myModal6275">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6275').style.display ='none'">×</span>
#  <strong>🚀Estagiário de UI</strong>
#  <p>Participação e auxílio na criação de telas<br/>
#  <br/>
#  Local: A empresa fica em Araraquara/SP, mas é possível trabalhar remotamente<br/>
#  Contratação: Estágio Bolsa R$ 15.600,00/ano (R$ 1.200,00/mês)<br/>
#  Mais informações sobre nossa cultura e projetos em nosso site: <a href="http://r2t.company" rel="noopener noreferrer" target="_blank">http://r2t.company</a><br/>
#  <br/>
#  🎯Habilidades:<br/>
#  -Estar cursando Ensino Superior em áreas relacionadas à Design, Produto, Análise de<br/>
#  Sistemas, entre outros;<br/>
#  -Conhecimento em Photoshop e Illustrator;<br/>
#  -Ser uma pessoa atenciosa aos detalhes;<br/>
#  -Ter interesse pela área de UI e UX<br/>
#  <br/>
#  🎯Diferenciais:<br/>
#  Conhecimento em software de prototipação como Adobe XD, Figma e/ou InVision.<br/>
#  <br/>
#  🎯Perfil:<br/>
#  Ser comunicativo; saber se comunicar remotamente é essencial; facilidade de trabalhar em equipe; responsabilidade para lidar com projetos em produção; capacidade de adquirir novos conhecimentos rapidamente; habilidade de trabalho colaborativo e descontraído; ser responsável por suas entregas.<br/>
#  <br/>
#  🎯Ambiente de trabalho:<br/>
#  Horário flexível.<br/>
#  Buscamos ter um ambiente diverso, aberto e liberal.<br/>
#  Free snacks<br/>
#  Envie seu currículo para o e-mail com o assunto: PS2021/01 - SEU NOME - Vaga Estagiário de UI para: <a href="mailto:recrutamento@r2t.company" rel="noopener noreferrer" target="_blank">recrutamento@r2t.company</a></p>
#  </div>
#  </div>, <div class="modal" id="myModal6240">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6240').style.display ='none'">×</span>
#  <strong>Oportunidade MB Labs</strong>
#  <p>As vagas que dispomos no momento atual:<br/>
#  - React Native;<br/>
#  - Node.JS<br/>
#  <br/>
#  Para enviar o CV basta cadastrar no e-mail <a href="mailto:rh@mblabs.com.br" rel="noopener noreferrer" target="_blank">rh@mblabs.com.br</a> </p>
#  </div>
#  </div>, <div class="modal" id="myModal6215">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6215').style.display ='none'">×</span>
#  <strong>Suporte Técnico</strong>
#  <p><a href="http://www.fatec.edu.br/wp-content/uploads/2020/11/Suporte_Tecnico.jpg" rel="noopener noreferrer" target="_blank"><img alt="" class="aligncenter size-medium wp-image-6216" height="195" src="http://www.fatec.edu.br/wp-content/uploads/2020/11/Suporte_Tecnico-300x195.jpg" width="300"/></a><br/>
#  <br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6199">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6199').style.display ='none'">×</span>
#  <strong>Analista Desenvolvedor Java</strong>
#  <p>Somos uma empresa de Tecnologia da Informação e temos como principais áreas de atuação:<br/>
#  - Sustentação em sistemas legados;<br/>
#  - Desenvolvimento de projetos no modelo esteiras ágeis e modelo cascata;<br/>
#  - Inovações em Inteligência artificial e RPA<br/>
#  <br/>
#  LINKS PARA CONHECER NOSSA EMPRESA:<br/>
#  LinkedIn: <a href="https://www.linkedin.com/company/liax-tecnologia-da-informa%C3%A7%C3%A3o/?viewAsMember=true" rel="noopener noreferrer" target="_blank">https://www.linkedin.com/company/liax-tecnologia-da-informa%C3%A7%C3%A3o/?viewAsMember=true</a><br/>
#  Facebook: <a href="https://www.facebook.com/LIAXBR" rel="noopener noreferrer" target="_blank">https://www.facebook.com/LIAXBR</a><br/>
#  <br/>
#  <br/>
#  INFORMAÇÕES SOBRE A VAGA:<br/>
#  Vaga para Analista desenvolvedor Java Júnior e Pleno.<br/>
#  Local:  Home Office full ou parcial.<br/>
#  Horário Flexível.<br/>
#  Cultura dinâmica.<br/>
#  Aprendizado constante.<br/>
#  <br/>
#  Buscamos pessoas que sejam híbrido-multitasking, que não tenham medo de perguntar, de dar opinião, e saber a hora de ouvir.  O colaborador irá ser apresentado a toda cadeia de que envolve o desenvolvimento de sistemas de forma a tornar-se um Analista Desenvolvedor mais completo.<br/>
#  <br/>
#  <strong>Os interessados devem enviar currículo para o e-mail: <a href="mailto:rh@liax.com.br" rel="noopener noreferrer" target="_blank">rh@liax.com.br</a> com assunto Vaga Liax / 2020 - E</strong><br/>
#  <br/>
#  <a href="http://www.fatec.edu.br/wp-content/uploads/2020/11/VAGA-ANALISTA-DESENVOLVEDOR.jpg"><img alt="" class="aligncenter size-medium wp-image-6200" height="300" src="http://www.fatec.edu.br/wp-content/uploads/2020/11/VAGA-ANALISTA-DESENVOLVEDOR-225x300.jpg" width="225"/></a><br/>
#  <br/>
#  <br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6191">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6191').style.display ='none'">×</span>
#  <strong>Estagiário(a) de Suporte Técnico</strong>
#  <p>Descrição: O profissional irá desempenhar função de atendimento de Service Desk a clientes, usuários de sistema de gestão comercial, administrativa e financeira.<br/>
#  Local de Trabalho: Sede MicroWork<br/>
#  Carga Horária: 4:30 horas (08h/12:30 ou 13:30/18h)<br/>
#  Bolsa auxilio: R$ 650,00 (seiscentos reais)<br/>
#  <br/>
#  Requisitos:<br/>
#  - Estar cursando nível superior ou técnico em informática, ou outros cursos;<br/>
#  - Conhecimentos gerais em informática;<br/>
#  - Gostar de trabalhar com atendimento a clientes;<br/>
#  <br/>
#  Caso tenha interesse enviar e-mail para: <a href="mailto:isabel.valls@microwork.inf.br" rel="noopener noreferrer" target="_blank">isabel.valls@microwork.inf.br</a><br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6189">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6189').style.display ='none'">×</span>
#  <strong>Estágio – Ensino Superior em Administração</strong>
#  <p><a href="http://www.fatec.edu.br/wp-content/uploads/2020/10/Publicacao-Estagio-POLICLINICA.jpg" rel="noopener noreferrer" target="_blank"><img alt="" class="aligncenter size-medium wp-image-6190" height="212" src="http://www.fatec.edu.br/wp-content/uploads/2020/10/Publicacao-Estagio-POLICLINICA-300x212.jpg" width="300"/></a><br/>
#  <br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6187">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6187').style.display ='none'">×</span>
#  <strong>Estágio – Ensino Superior em Administração e Recursos Humanos</strong>
#  <p><a href="http://www.fatec.edu.br/wp-content/uploads/2020/10/Publicacao-Estagio-ADM.jpg" rel="noopener noreferrer" target="_blank"><img alt="" class="aligncenter size-medium wp-image-6188" height="212" src="http://www.fatec.edu.br/wp-content/uploads/2020/10/Publicacao-Estagio-ADM-300x212.jpg" width="300"/></a><br/>
#  <br/>
#  </p>
#  </div>
#  </div>, <div class="modal" id="myModal6185">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6185').style.display ='none'">×</span>
#  <strong>Processo seletivo para o Nova Geração PwC</strong>
#  <p>O processo é voltado para estudantes de cursos de graduação em Administração, Ciências Atuariais, Ciências Contábeis, Ciências Econômicas, Engenharias e cursos de Tecnologia da Informação <br/>
#  <br/>
#  É necessário ter disponibilidade para trabalhar 40 horas semanais e inglês a partir de intermediário. <br/>
#  <br/>
#  As inscrições estão abertas até o dia 22/10/20. <br/>
#  <br/>
#    <br/>
#  <strong>Mais informações disponíveis nesse link<a href="https://vagas.ciadetalentos.com.br/hotsite/novageracaopwc?utm_source=universidades&amp;utm_medium=outlook&amp;utm_campaign=PwC_universidades_19102020" rel="noopener noreferrer" target="_blank">https://vagas.ciadetalentos.com.br/hotsite/novageracaopwc?utm_source=universidades&amp;utm_medium=outlook&amp;utm_campaign=PwC_universidades_19102020</a>. </strong></p>
#  </div>
#  </div>, <div class="modal" id="myModal6180">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6180').style.display ='none'">×</span>
#  <strong>Oportunidade de trabalho para www.jbcases.com.br</strong>
#  <p>Oportunidade de trabalho para <a href="http://www.jbcases.com.br" rel="noopener noreferrer" target="_blank">www.jbcases.com.br</a><br/>
#  <br/>
#  Vaga aberta para Designer Gráfico ou Arte finalista com conhecimentos em: Corel Draw, Photoshop, Illustrator<br/>
#  Experiência com diagramação e impressão é um diferencial (impressora Lef-200 para cases de celular)<br/>
#  Enviar Portfólio ou link com exemplos de trabalhos já realizados anteriormente para o email <a href="mailto:jb.artesdesigner@gmail.com" rel="noopener noreferrer" target="_blank">jb.artesdesigner@gmail.com</a>.<br/>
#  <br/>
#  Temos preferência para alunos do último/penúltimo ano de curso.<br/>
#  <br/>
#  Telefone para contato: (19) 97106-2526</p>
#  </div>
#  </div>, <div class="modal" id="myModal6167">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6167').style.display ='none'">×</span>
#  <strong>Oportunidade de Estágio – NUBE</strong>
#  <p>RAMO DA EMPRESA<br/>
#  - Comércio de acessórios e cosméticos.<br/>
#  <br/>
#  CURSOS<br/>
#  - Ensino Médio;<br/>
#  - EJA - Educação de Jovens e Adultos;<br/>
#  - Técnico em Administração/Marketing/Publicidade;<br/>
#  - Ensino Médio integrado a Administração/Marketing/Publicidade.<br/>
#  <br/>
#  ATIVIDADES<br/>
#  - Manter a organização do local;<br/>
#  - Realizar atendimento aos clientes;<br/>
#  - Efetuar a venda dos produtos da empresa;<br/>
#  - Auxiliar com as demais atividades da área.<br/>
#  <br/>
#  REQUISITOS<br/>
#  - Conclusão entre o 1° semestre de 2021 até o 1° semestre de 2023.<br/>
#  <br/>
#  BENEFÍCIOS<br/>
#  - Bolsa auxílio no valor de R$ 600,00 por mês;<br/>
#  - Auxílio transporte;<br/>
#  - Recesso remunerado;<br/>
#  - Possibilidade de prorrogação e efetivação.<br/>
#  <br/>
#  HORÁRIO E LOCAL DE ESTÁGIO<br/>
#  De segunda a segunda-feira, das 10h às 16h, com 1h de intervalo e uma folga semanal.<br/>
#  Vila Mollon IV - Santa Bárbara d`Oeste<br/>
#  Anote o código: 190150 e ligue para (19) 3004-6290.</p>
#  </div>
#  </div>, <div class="modal" id="myModal6166">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6166').style.display ='none'">×</span>
#  <strong>Vaga para Técnico em Informática</strong>
#  <p>Função: Suporte técnico ao usuário final na utilização de sistema.<br/>
#  <br/>
#  Conhecimento:<br/>
#  * Sistema operacional Windows 7, 8 e 10<br/>
#  * Rede de computadores Windows: compartilhamento, mapeamento e definição de ip;<br/>
#  * Instalação e configuração de hardware como impressoras e certificados digital;<br/>
#  <br/>
#  Remuneração:<br/>
#  - Salário<br/>
#  - Vale Transporte<br/>
#  - Convênio Odontológico<br/>
#  - Convênio Médico Percentual.<br/>
#  <br/>
#  <strong>Enviar currículo para: <a href="mailto:vagner@prodataweb.com.br" rel="noopener noreferrer" target="_blank">vagner@prodataweb.com.br</a> </strong></p>
#  </div>
#  </div>, <div class="modal" id="myModal6164">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6164').style.display ='none'">×</span>
#  <strong>Processo Seletivo MB.Labs 2020/2021</strong>
#  <p>Olá tripulantes, muito prazer!<br/>
#  Meu nome é Luan Santiago e sejam bem vindos ao processo seletivo MB.Labs 2020/2021!<br/>
#  <br/>
#  Estamos muito próximos de embarcar nessa viagem e para isso pedimos que apertem os cintos e se preparem para decolar na carreira. Para isso, necessitamos:<br/>
#  - Desenvolvedor Android Pleno<br/>
#  - Desenvolvedor Android Sênior<br/>
#  - Desenvolvedor iOS Pleno<br/>
#  - Desenvolvedor iOS Sênior<br/>
#  - Desenvolvedor Node.JS Pleno<br/>
#  - Desenvolvedor Node.JS Sênior<br/>
#  - Desenvolvedor Node.JS Estágio<br/>
#  - Desenvolvedor .NET Pleno<br/>
#  - Desenvolvedor .NET Junior<br/>
#  - Desenvolvedor .NET Estágio<br/>
#  - Desenvolvedor React Native Pleno<br/>
#  - Desenvolvedor React Native Junior<br/>
#  - Desenvolvedor React Native Estágio<br/>
#  - RH Estágio  <br/>
#  <br/>
#  Se você quer participar ou conhece alguém que esteja em busca de novos vôos, nos envie seu CV.<br/>
#  <br/>
#  É muito fácil, veja:<br/>
#  <strong>Enviar o CV no e-mail <a href="mailto:rh@mblabs.com.br" rel="noopener noreferrer" target="_blank">rh@mblabs.com.br</a> com cópia para luan.santiago@mblabs.com.br e mencionar no corpo do e-mail que é indicação de "LUAN SANTIAGO". </strong><br/>
#  <em>Exemplo: "Olá, MB. Tudo bem? Me chamo Ana e encaminho o meu currículo para análise. O funcionário Luan Santiago indicou-me para essa vaga".</em><br/>
#  Vem para a MB!</p>
#  </div>
#  </div>, <div class="modal" id="myModal6161">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6161').style.display ='none'">×</span>
#  <strong>Programa de Estágio HST 2021</strong>
#  <p><a href="http://www.fatec.edu.br/wp-content/uploads/2020/10/hst.png"><img alt="" class="aligncenter size-medium wp-image-6162" height="300" src="http://www.fatec.edu.br/wp-content/uploads/2020/10/hst-300x300.png" width="300"/></a><br/>
#  <br/>
#  Já imaginou fazer parte de uma empresa referência em segurança e soluções para meios de pagamentos? Se você é universitário e tem o sonho de se desenvolver na área de T.I, essa é a sua oportunidade!<br/>
#  Por mais de 30 anos, a HST tem implementado soluções para instituições financeiras e varejistas em toda a América Latina. Com escritórios em Campinas/SP/Brasil e Miami/FL/USA, contamos com mais de 150 colaboradores que buscam solucionar os mais complexos desafios, daqueles que transformam a vida das pessoas.<br/>
#  As inscrições para o programa de estágio vão de 6/10 à 31/10 e devem ser feitas pelo LinkedIn. Possui o perfil que procuramos? Acesse o link e inscreva-se:<br/>
#  #HSTransforma<br/>
#  <br/>
#  <strong>LINK PARA INSCRIÇÃO: <a href="https://www.linkedin.com/jobs/view/2189059328/?refId=5611405291601901872104" rel="noopener noreferrer" target="_blank">https://www.linkedin.com/jobs/view/2189059328/?refId=5611405291601901872104</a></strong></p>
#  </div>
#  </div>, <div class="modal" id="myModal6160">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6160').style.display ='none'">×</span>
#  <strong>SELEÇÃO DE ESTÁGIO 2020 – área Têxtil, Moda ou Química.</strong>
#  <p>A MTECH Indústria e Comércio de Produtos Químicos Ltda. está abrindo uma vaga de estágio neste ano de 2020 para alunos que estiverem cursando na área Têxtil, Moda ou Química.<br/>
#  <br/>
#  Nossa empresa é voltada para área têxtil, trabalhamos com produtos químicos aplicados desde o fio até o acabamento do tecido.<br/>
#  <br/>
#  O estágio é em nosso laboratório de análise de produtos químicos, de aplicação em tecidos e na lavanderia.<br/>
#  <br/>
#  Temos toda uma estrutura como se fosse uma mini produção na área têxtil.<br/>
#  <br/>
#  <strong>Os interessados deverão enviar os currículos para o e-mail <a href="mailto:luis@mtechbrasil.com.br" rel="noopener noreferrer" target="_blank">luis@mtechbrasil.com.br</a></strong></p>
#  </div>
#  </div>, <div class="modal" id="myModal6157">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6157').style.display ='none'">×</span>
#  <strong>Programa de Estágio da Raízen 2021</strong>
#  <p><strong>Sobre a empresa</strong><br/>
#  </p><p align="justify">A Raízen se destaca como uma das empresas de energia mais competitivas do mundo e uma das maiores em faturamento no Brasil, atuando em todas as etapas do processo: cultivo da cana, produção de açúcar, etanol e energia, comercialização, logística interna e de exportação, distribuição e varejo de combustíveis.</p><br/>
#  <br/>
#  <strong>Sobre o processo</strong><br/>
#  <p align="justify">O programa de estágio da Raízen é para quem tá cheio de energia. Pronto para agarrar as oportunidades, vestir a camisa e começar a carreira num time que joga junto, valorizando o melhor de cada um. O estágio na Raízen é desenvolvimento puro, aqui todos participam ativamente dos nossos projetos e se desenvolvem muito com o apoio de uma equipe preparada e um plano de desenvolvimento focado no estagiário.</p><br/>
#  <br/>
#  <strong>Pré-requisitos</strong><br/>
#  * Alunos do ensino superior, todos os cursos; <br/>
#  * Conclusão da graduação prevista para daqui um ano (no mínimo); <br/>
#  * Disponibilidade para estagiar no mínimo 6 horas por dia ou 30 horas por semana.<br/>
#  <br/>
#  <strong>As inscrições são através do site: <a href="https://bit.ly/raizen2021" rel="noopener noreferrer" target="_blank">https://bit.ly/raizen2021</a></strong>
#  </div>
#  </div>, <div class="modal" id="myModal6153">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6153').style.display ='none'">×</span>
#  <strong>Analista desenvolvedor Java Júnior e Pleno</strong>
#  <p>Local:  Home Office full ou parcial.<br/>
#  Horário Flexível.<br/>
#  Cultura dinâmica.<br/>
#  Aprendizado constante.<br/>
#  <br/>
#  <br/>
#  Buscamos pessoas que sejam híbrido-multitasking, que não tenham medo de perguntar, de dar opinião, e saber a hora de ouvir.  O colaborador irá ser apresentado a toda cadeia de que envolve o desenvolvimento de sistemas de forma a tornar-se um Analista Desenvolvedor mais completo.<br/>
#  <br/>
#  <a href="http://www.fatec.edu.br/wp-content/uploads/2020/10/Vaga-Analista-Desenvolvedor.jpg"><img alt="" class="aligncenter size-medium wp-image-6154" height="300" src="http://www.fatec.edu.br/wp-content/uploads/2020/10/Vaga-Analista-Desenvolvedor-225x300.jpg" width="225"/></a><br/>
#  <br/>
#  Interessado enviar currículo para o e-mail <a href="mailto:rh@liax.com.br" rel="noopener noreferrer" target="_blank">rh@liax.com.br</a> especificar no assunto <strong>Vaga Liax / 2020 - E</strong></p>
#  </div>
#  </div>, <div class="modal" id="myModal6152">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6152').style.display ='none'">×</span>
#  <strong>GERENTE DE DESENVOLVIMENTO DE SISTEMAS</strong>
#  <p>Gerenciar o desenvolvimento em PHP/JAVA para Sistema ERP, Loja Virtual e Projetos Especiais.<br/>
#  <br/>
#  Requisitos:<br/>
#  <br/>
#  - Experiência em gestão de equipe e projetos<br/>
#  <br/>
#  - Domínio em Sistema ERP<br/>
#  <br/>
#  - Domínio em NF-e, NFS-e, NFC-e<br/>
#  <br/>
#  - Domínio em Sistema Bancos / CNAB<br/>
#  <br/>
#  - Domínio em Linguagens de Programação (PHP e JAVA);<br/>
#  <br/>
#  - Domínio em Banco de Dados SQL (PostgreSQL);<br/>
#  <br/>
#  Interessado? Envie seu currículo para <a href="mailto:rh@alfanetworks.com.br" rel="noopener noreferrer" target="_blank">rh@alfanetworks.com.br</a><br/>
#  <br/>
#  Colocar assunto do e-mail: GERENTE DE DESENVOLVIMENTO DE SISTEMAS</p>
#  </div>
#  </div>, <div class="modal" id="myModal6151">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6151').style.display ='none'">×</span>
#  <strong>PROGRAMADOR PHP / JAVA</strong>
#  <p>Análise e desenvolvimento em PHP para Sistema ERP, Loja Virtual e Projetos Especiais.<br/>
#  <br/>
#  Requisitos:<br/>
#  <br/>
#  - Domínio em Sistema ERP<br/>
#  <br/>
#  - Domínio em NF-e, NFS-e, NFC-e<br/>
#  <br/>
#  - Domínio em Sistema Bancos / CNAB<br/>
#  <br/>
#  - Domínio em Linguagens de Programação (PHP e JAVA);<br/>
#  <br/>
#  - Experiência em Banco de Dados SQL (PostgreSQL);<br/>
#  <br/>
#  Interessado? Envie seu currículo para <a href="mailto:rh@alfanetworks.com.br" rel="noopener noreferrer" target="_blank">rh@alfanetworks.com.br</a><br/>
#  <br/>
#  Colocar assunto do e-mail: PROGRAMADOR PHP / JAVA</p>
#  </div>
#  </div>, <div class="modal" id="myModal6150">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6150').style.display ='none'">×</span>
#  <strong>ESTÁGIO EM PROGRAMAÇÃO/SUPORTE TÉCNICO</strong>
#  <p>Desenvolver Sistema ERP, Loja Virtual e Projetos Especiais. Realizar correções e customizações. Prestar suporte técnico aos clientes.<br/>
#  <br/>
#  Requisitos:<br/>
#  <br/>
#  - Cursando ensino superior relacionado à área<br/>
#  <br/>
#  - Conhecimento em Linguagens de Programação (PHP e JAVA)<br/>
#  <br/>
#  - Conhecimento em Banco de Dados SQL (PostgreSQL)<br/>
#  <br/>
#  - Conhecimentos em Javascript / jQuery<br/>
#  <br/>
#  Interessado? Envie seu currículo para <a href="mailto:estagio@alfanetworks.com.br" rel="noopener noreferrer" target="_blank">estagio@alfanetworks.com.br</a><br/>
#  <br/>
#  Colocar assunto do e-mail: ESTÁGIO EM PROGRAMAÇÃO/SUPORTE TÉCNICO</p>
#  </div>
#  </div>, <div class="modal" id="myModal6149">
#  <div class="modal-content">
#  <span class="close" onclick="document.getElementById('myModal6149').style.display ='none'">×</span>
#  <strong>ESTÁGIO EM MARKETING</strong>
#  <p>Produção de conteúdo. Realizar publicações. Criar artes gráficas.<br/>
#  <br/>
#  Requisitos:<br/>
#  <br/>
#  - Cursando ensino superior relacionado à área<br/>
#  <br/>
#  - Boa comunicação verbal e escrita<br/>
#  <br/>
#  - Habilidade com Redes Sociais<br/>
#  <br/>
#  - Conhecimento em Google ADS, Facebook ADS e Instagram ADS<br/>
#  <br/>
#  - Conhecimento em Photoshop, Illustrator e Pacote Office<br/>
#  <br/>
#  - Diferencial: Conhecimento em edição de vídeo<br/>
#  <br/>
#  Interessado? Envie seu currículo para <a href="mailto:estagio@alfanetworks.com.br" rel="noopener noreferrer" target="_blank">estagio@alfanetworks.com.br</a><br/>
#  <br/>
#  Colocar assunto do e-mail: ESTÁGIO EM MARKETING</p>
#  </div>
#  </div>]

# %%
len(vagas)
# Out:
# 29

# %%
vagas[28]
# Out:
# <div class="modal" id="myModal6149">
# <div class="modal-content">
# <span class="close" onclick="document.getElementById('myModal6149').style.display ='none'">×</span>
# <strong>ESTÁGIO EM MARKETING</strong>
# <p>Produção de conteúdo. Realizar publicações. Criar artes gráficas.<br/>
# <br/>
# Requisitos:<br/>
# <br/>
# - Cursando ensino superior relacionado à área<br/>
# <br/>
# - Boa comunicação verbal e escrita<br/>
# <br/>
# - Habilidade com Redes Sociais<br/>
# <br/>
# - Conhecimento em Google ADS, Facebook ADS e Instagram ADS<br/>
# <br/>
# - Conhecimento em Photoshop, Illustrator e Pacote Office<br/>
# <br/>
# - Diferencial: Conhecimento em edição de vídeo<br/>
# <br/>
# Interessado? Envie seu currículo para <a href="mailto:estagio@alfanetworks.com.br" rel="noopener noreferrer" target="_blank">estagio@alfanetworks.com.br</a><br/>
# <br/>
# Colocar assunto do e-mail: ESTÁGIO EM MARKETING</p>
# </div>
# </div>

# %%
vaga = vagas[28]

# %%
nome = vaga.find("strong")
conteudo = vaga.find("p")
contato = vaga.find("a").text

# %%
contato
# Out:
# 'estagio@alfanetworks.com.br'

# %%
class FatecEstagio:
  def __init__(self,bs_vaga=None):

    if bs_vaga is not None:
      self.nome = bs_vaga.find("strong")
      self.conteudo = bs_vaga.find("p")
      self.contato = bs_vaga.find("a").text

# %%
p = FatecEstagio(vaga)

# %%
p.conteudo
# Out:
# <p>Produção de conteúdo. Realizar publicações. Criar artes gráficas.<br/>
# <br/>
# Requisitos:<br/>
# <br/>
# - Cursando ensino superior relacionado à área<br/>
# <br/>
# - Boa comunicação verbal e escrita<br/>
# <br/>
# - Habilidade com Redes Sociais<br/>
# <br/>
# - Conhecimento em Google ADS, Facebook ADS e Instagram ADS<br/>
# <br/>
# - Conhecimento em Photoshop, Illustrator e Pacote Office<br/>
# <br/>
# - Diferencial: Conhecimento em edição de vídeo<br/>
# <br/>
# Interessado? Envie seu currículo para <a href="mailto:estagio@alfanetworks.com.br" rel="noopener noreferrer" target="_blank">estagio@alfanetworks.com.br</a><br/>
# <br/>
# Colocar assunto do e-mail: ESTÁGIO EM MARKETING</p>
